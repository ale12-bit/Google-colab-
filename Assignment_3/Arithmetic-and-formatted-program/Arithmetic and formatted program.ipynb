# %%
num1_str = input("Enter the first number: ")
num2_str = input("Enter the second number: ")

try:
    num1 = float(num1_str)
    num2 = float(num2_str)

    addition = num1 + num2
    subtraction = num1 - num2
    multiplication = num1 * num2

    print(f"Addition: {num1} + {num2} = {addition}")
    print(f"Subtraction: {num1} - {num2} = {subtraction}")
    print(f"Multiplication: {num1} * {num2} = {multiplication}")

    if num2 != 0:
        division = num1 / num2
        print(f"Division: {num1} / {num2} = {division}")
    else:
        print("Division by zero is not allowed.")

except ValueError:
    print("Invalid input. Please enter valid numbers.")
# Out:
# Enter the first number: 20
# Enter the second number: 30
# Addition: 20.0 + 30.0 = 50.0
# Subtraction: 20.0 - 30.0 = -10.0
# Multiplication: 20.0 * 30.0 = 600.0
# Division: 20.0 / 30.0 = 0.6666666666666666

# %%
name = input("Enter your name: ")
age = input("Enter your age: ")
course = input("Enter your course: ")

print(f"Hello, {name}! You are {age} years old and currently studying {course}.")
# Out:
# Enter your name: Alex
# Enter your age: 90
# Enter your course: Hospitality manager
# Hello, Alex ! You are 90 years old and currently studying Hospitality manager .
